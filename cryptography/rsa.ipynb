# %%
import sympy.ntheory as nt
import matplotlib.pyplot as plt

# %%
print(nt.totient(8))
# Out:
# 4

# %%
axes_x = range(1, 100)

# %%
plt.plot(axes_x, [nt.totient(number) for number in axes_x])

# %%
numbers = [1, 2, 3, 4, 5, 6]

# %%
pow_numbers = [number ** 2 for number in numbers]

# %%
pow_numbers
# Out:
# [1, 4, 9, 16, 25, 36]
